# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
["cat","bat","rat","elephant"]
# Out:
# ['cat', 'bat', 'rat', 'elephant']

# %%
["hello",3.1415,True, None,42]
# Out:
# ['hello', 3.1415, True, None, 42]

# %%
spam=["cat","bat","rat","elephant"]
spam
# Out:
# ['cat', 'bat', 'rat', 'elephant']

# %%
spam[0]
# Out:
# 'cat'

# %% [markdown]
# spam[1]

# %%
spam[1]
# Out:
# 'bat'

# %%
spam[2]
# Out:
# 'rat'

# %%
spam[3]
# Out:
# 'elephant'

# %%
"hello " + spam[0]
# Out:
# 'hello cat'

# %%
"The " + spam[1] + " ate the " + spam[0] + "."
# Out:
# 'The bat ate the cat.'

# %%
spam[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 spam[100]
#
# IndexError: list index out of range

# %%
spam=["cat","bat","rat","elephant"]
spam[1]
# Out:
# 'bat'

# %%
spam[1.0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 spam[1.0]
#
# TypeError: list indices must be integers or slices, not float

# %%
spam[int(1.0)]
# Out:
# 'bat'

# %%
spam[int(2.0)]
# Out:
# 'rat'

# %%
spam=[["cat", "bat"],[10,20,30,40,50]]
spam[0]
# Out:
# ['cat', 'bat']

# %%
spam[0][1]
# Out:
# 'bat'

# %%
spam[1][4]
# Out:
# 50

# %%
spam=["cat","bat" ,"rat", "elephant"]

# %%
spam[-1]
# Out:
# 'elephant'

# %%
"The "+ spam[-1]+ "is afraid of the "+ spam[-3]+ " ."
# Out:
# 'The elephantis afraid of the bat .'

# %%
spam[1:4]
# Out:
# ['bat', 'rat', 'elephant']

# %%
spam[1]="aardvark"

# %% [markdown]
# spam[1]

# %%
spam[1]
# Out:
# 'aardvark'

# %%
spam[2]=spam[1]

# %%
spam
# Out:
# ['cat', 'aardvark', 'aardvark', 'elephant']

# %%
spam[-1]=123445

# %%
spam
# Out:
# ['cat', 'aardvark', 'aardvark', 123445]

# %%
[1,2,3]+["a","b","c"]
# Out:
# [1, 2, 3, 'a', 'b', 'c']

# %%
["x","y","c"]*3
# Out:
# ['x', 'y', 'c', 'x', 'y', 'c', 'x', 'y', 'c']

# %%
spam=[1,2,3]
spam=spam+["x","y","z"]
spam
# Out:
# [1, 2, 3, 'x', 'y', 'z']

# %%
spam=["cat ","bat","rat", "elephant"]
del spam[2]
spam
# Out:
# ['cat ', 'bat', 'elephant']

# %%
del spam[2]

# %%
spam
# Out:
# ['cat ', 'bat']

# %%
catname1="Zophie"
catname2="pooka"
catname3=
catname4=
catname5=
catname6=
# Out:
#   Cell In[55], line 3
#     catname3=
#              ^
# SyntaxError: invalid syntax

# %%
print("Enter the name of cat 1: ")
catName1= input()
print("Enter the name of cat 2: ")
catName2= input()
print("Enter the name of cat 3: ")
catName3= input()
print("Enter the name of cat 4: ")
catName4= input()
print("Enter the name of cat 5: ")
catName5= input()
print("Enter the name of cat 6: ")
catName6= input()

print("The cat names are:")
print(catName1+""+catName2+""+catName3+""+catName4+""+catName5+""+catName6)
# Out:
# Enter the name of cat 1:
#  s
# Enter the name of cat 2:
#  d
# Enter the name of cat 3:
#  g
# Enter the name of cat 4:
#  h
# Enter the name of cat 5:
#  yu
# Enter the name of cat 6:
#  u
# The cat names are:
# sdghyuu

# %%
catNames=[]
while True:
    print("enter the name of cat"+str(len(catNames)+1)+"(Or enter nothing to stop)")
    name=input()
    if name =="":
        break
    catNames=catNames+[name]
print("The cat names are:"
     )
for name in catNames:
    print("" +name)
# Out:
# enter the name of cat1(Or enter nothing to stop)
#  q
# enter the name of cat2(Or enter nothing to stop)
#  s
# enter the name of cat3(Or enter nothing to stop)
#  d
# enter the name of cat4(Or enter nothing to stop)
#  g
# enter the name of cat5(Or enter nothing to stop)
#  s
# enter the name of cat6(Or enter nothing to stop)
#  de
# enter the name of cat7(Or enter nothing to stop)
# enter the name of cat8(Or enter nothing to stop)
# The cat names are:
# q
# s
# d
# g
# s
# de

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(4):
    print(i
         )
# Out:
# 0
# 1
# 2
# 3

# %%
for i in [0,1,2,3]:
    print(i
         
         )
# Out:
# 0
# 1
# 2
# 3

# %%
supplies=["pen","staplers", "flame-throwers", "binders"]
for i in range(len(supplies)):
    print("Indes "+str(i)+" in supplies is:"+supplies[i])
# Out:
# Indes 0 in supplies is:pen
# Indes 1 in supplies is:staplers
# Indes 2 in supplies is:flame-throwers
# Indes 3 in supplies is:binders

# %%
len(supplies)
# Out:
# 4

# %%
"howdy" in ["hello","hi","howdy","heyas"]
# Out:
# True

# %%
spam=["hello","hi","howdy","heyas"]
"cat" in spam
# Out:
# False

# %%
"cat" not in spam
# Out:
# True

# %%
myPets=["Zophie","Pooka","Fat-tail"
       ]
print("enter a pet name:")
name=input()
if name not in myPets:
    print("I do not have a pet names "+name+ " .")
else:
    print(name+" is my pet.")
# Out:
# enter a pet name:
#  s
# I do not have a pet names s .

# %%
#4.2.3多重赋值技巧

# %%
cat=["fat","black","Loud"]
size,color,disposition=cat

# %%
# 4.3

# %%
spam=42
spam=spam +1

# %%
spam
# Out:
# 43

# %%
spam=42
spam+=1
spam
# Out:
# 43

# %%
# 4.4

# %%
# 4.4.1

# %%
spam=["hello","hi","howdy","heyas"]
spam.index("hello")
# Out:
# 0

# %%
spam.index("hi")
# Out:
# 1

# %%
spam.index("howdy", "howdy")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 spam.index("howdy", "howdy")
#
# TypeError: slice indices must be integers or have an __index__ method

# %%
#重复的值，只出现第一次出现的下标，

# %%
#4.4.2 append(). intsert()
#4.4.3 remove()
#4.4.4 sort()

# %%
spam=[2,5,3.14,1,-7]
spam.sort()
spam
# Out:
# [-7, 1, 2, 3.14, 5]

# %%
spam=["ants","cats","dogs","badgers","elephants"]
spam.sort()
spam
# Out:
# ['ants', 'badgers', 'cats', 'dogs', 'elephants']

# %%
spam.sort(reverse=True)
spam
# Out:
# ['elephants', 'dogs', 'cats', 'badgers', 'ants']

# %%
spam.sort(key=str.lower)
spam
# Out:
# ['ants', 'badgers', 'cats', 'dogs', 'elephants']

# %%
#4.5
spam=["ants",
     "cats"          ,
               "dogs",        
                "badgers",
               "elephants"]
print(spam)
# Out:
# ['ants', 'cats', 'dogs', 'badgers', 'elephants']

# %%
print("Four score and seven"+ \
      " years ago...")
# Out:
# Four score and seven years ago...

# %%
import random
messages=["It is certain",
         "It is decidedly so",
         "Yes definitely",
         "Ask again later",
          "d",
          "sdfg"
          ,"df"
          ,"dgdaf",
          "dffd"
    
]
print(messages[random.randint(0,len(messages), - 1)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 13
#       1 import random
#       2 messages=["It is certain",
#       3          "It is decidedly so",
#       4          "Yes definitely",
#    (...)
#      11
#      12 ]
# ---> 13 print(messages[random.randint(0,len(messages), - 1)])
#
# TypeError: Random.randint() takes 3 positional arguments but 4 were given

# %%
name="Zophie a cat"
newName=name[0:7]+ "the" + name[8:12]
newName
# Out:
# 'Zophie the cat'

# %%
name[0:7]
# Out:
# 'Zophie '

# %%
#4.6.2

# %%
eggs=("hello",42,0.5)
eggs[0]
# Out:
# 'hello'

# %%
type(eggs)
# Out:
# tuple

# %%
type(("hello",))
# Out:
# tuple

# %%
type(("hello"))
# Out:
# str

# %%
type(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 type(hello)
#
# NameError: name 'hello' is not defined

# %%
#4.6.3

# %%
tuple("cat")
# Out:
# ('c', 'a', 't')

# %%
tuple(["cat","dog",5])
# Out:
# ('cat', 'dog', 5)

# %%
list(("cat","dog",5))
# Out:
# ['cat', 'dog', 5]

# %%
#4.7

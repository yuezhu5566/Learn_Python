# %% [markdown]
# # 6

# %% [markdown]
# ## 6.1

# %% [markdown]
# ### 6.1.1

# %% [markdown]
# ### 6.1.2

# %% [markdown]
# ### 6.1.3 转义字符

# %% [raw]
# \'
# \"
# \t
# \n   换行
# \\

# %%
print("Hello there!\nHow are you?\nI\'m doing fine.")
# Out:
# Hello there!
# How are you?
# I'm doing fine.

# %% [markdown]
# ### 6.1.5

# %%
print('''Dear Alice,

Eve's cat has been arrested for catnapping, cat burglary, and extortion.

Sincerely,Bob''')
# Out:
# Dear Alice,
#
# Eve's cat has been arrested for catnapping, cat burglary, and extortion.
#
# Sincerely,Bob

# %%
""" This is a test Python program.
Written by AL Sweigart al

This program was designed for Python 3, not Python 2.
"""

def spam():
    """This is a multiline comment to help
    expalin what the spam() function does."""
    print("Hello!")

spam
# Out:
# <function __main__.spam()>

# %% [markdown]
# ### 6.1.7

# %%
spam="Hello world!"
spam[0]
# Out:
# 'H'

# %%
spam[-1]
# Out:
# '!'

# %%
spam[0:5]
# Out:
# 'Hello'

# %%
spam[:5]
# Out:
# 'Hello'

# %%
spam[5]
# Out:
# ' '

# %%
spam[6:]
# Out:
# 'world!'

# %% [markdown]
# ### 6.1.8

# %%
"Hello" in "Hello World!"
# Out:
# True

# %%
"HELLO" in "Hello World!"
# Out:
# False

# %%
"" in "spam"
# Out:
# True

# %%
"cat" not in "cats and dogs"
# Out:
# False

# %% [markdown]
# ### 6.2

# %%
spam="hello world"
spam=spam.upper()

# %%
spam
# Out:
# 'HELLO WORLD'

# %%
spam=spam.lower()
spam
# Out:
# 'hello world'

# %%
print("How are you?")
feeling= input()
if feeling.lower()=="great":
    print("I feel great too.")
else:
    print("I hope the rest of your day is good")
# Out:
# How are you?
#  GrEat
# I feel great too.

# %%
print("How are you?")
feeling= input()
if feeling.lower()=="great":
    print("I feel great too.")
else:
    print("I hope the rest of your day is good")
# Out:
# How are you?
#  geat
# I hope the rest of your day is good

# %%
spam="Hello world!"
spam.islower()
# Out:
# False

# %%
spam.isupper()
# Out:
# False

# %%
"HELLO".upper()
# Out:
# 'HELLO'

# %%
"hello".upper().lower().upper()
# Out:
# 'HELLO'

# %%
"abc12345".islower()
# Out:
# True

# %%
"12345".islower()
# Out:
# False

# %% [markdown]
# ### 6.2.2

# %%
"hello".isalpha()
# Out:
# True

# %%
"hello123".isalpha()
# Out:
# False

# %%
"hello123".isalnum()
# Out:
# True

# %%
while True:
    print("Enter your age: ")
    age=input()
    if age.isdecimal():
        break
    print("Please enter a number for your age.")

while True:
    print("Select a new password(letters and numbers only):")
    password = input()
    if password.isalnum():
       break
    print("Passwords can only have letters and numbers.")
# Out:
# Enter your age:
#  5
# Select a new password(letters and numbers only):
#  s

# %%
while True:
    print("Select a new password(letters and numbers only):")
    password = input()
    if password.isalnum():
       break
    print("Passwords can only have letters and numbers.")
# Out:
# Select a new password(letters and numbers only):
#  d

# %% [markdown]
# ### 6.2.3

# %%
"hello world".startswith("hello")
# Out:
# True

# %%
"Hello world!".endswith("world!")
# Out:
# True

# %%
"abc123".startswith("abcdef")
# Out:
# False

# %%
"abc123".endswith("12")
# Out:
# False

# %%
"Hello world!".startswith("Hello world!")
# Out:
# True

# %%
"Hello world!".endswith("Hello world!")
# Out:
# True

# %% [markdown]
# ### 6.2.4
#
# #加入字符中间

# %%
",".join(["cats","rats","bats"])
# Out:
# 'cats,rats,bats'

# %%
" ".join(["my", "name","is", "Simon"])
# Out:
# 'my name is Simon'

# %%
"BAC".join(["My", "name", "is", "Simon"])
# 加入字符中间
# Out:
# 'MyBACnameBACisBACSimon'

# %%
"My name is Simon".split()
# Out:
# ['My', 'name', 'is', 'Simon']

# %%
"MyBACnameBACisBACSimon".split("BAC")
# Out:
# ['My', 'name', 'is', 'Simon']

# %%
"My name is Simon".split("m")
# Out:
# ['My na', 'e is Si', 'on']

# %%
spam="""Dear Alice,
How have you been? I am fine.
There is a container in fridge
that is labeled "Milk Experiment".

Please do not drink it.
Sincerely,
Bob"""
spam.split("/n")
# Out:
# ['Dear Alice,\nHow have you been? I am fine.\nThere is a container in fridge\nthat is labeled "Milk Experiment".\n\nPlease do not drink it.\nSincerely,\nBob']

# %% [markdown]
# ### 6.2.5

# %%
"Hello".rjust(10)
# Out:
# '     Hello'

# %%
"Hello".rjust(20)
# Out:
# '               Hello'

# %%
"Hello world".rjust(20)
# Out:
# '         Hello world'

# %%
"hello".ljust(10)
# Out:
# 'hello     '

# %%
"Hello".rjust(20,"*")
# Out:
# '***************Hello'

# %%
"Hello".ljust(20,"-")
# Out:
# 'Hello---------------'

# %%
"hello".center(20)
# Out:
# '       hello        '

# %%
"hello".center(20,"=")
# Out:
# '=======hello========'

# %%
def printPicnic(itemsDict, leftWidth, rightWidth):
    print("PICNIC ITEMS".center(leftWidth + rightWidth, "-"))
    for k,v in itemsDict.items():
              print(k.ljust(leftWidth, ".")+str(v).rjust(rightWidth))
picnicItems = {"sandwiches": 4, "apple": 12,"cups": 4, "cookies": 800}
printPicnic(picnicItems,12,5)    
printPicnic(picnicItems,20,6)
# page:104
# Out:
# ---PICNIC ITEMS--
# sandwiches..    4
# apple.......   12
# cups........    4
# cookies.....  800
# -------PICNIC ITEMS-------
# sandwiches..........     4
# apple...............    12
# cups................     4
# cookies.............   800

# %% [markdown]
# ### 6.2.6

# %%
spam=" Hello world "
spam.strip()
# Out:
# 'Hello world'

# %%
spam.lstrip()
# Out:
# 'Hello world '

# %%
spam.rstrip()
# Out:
# ' Hello world'

# %%
spam= "SpamSpamBaconSpamEggsSpamSpam"
spam.strip("ampS")
# Out:
# 'BaconSpamEggs'

# %% [markdown]
# ### 6.2.7

# %%
import pyperclip
pyperclip.copy("Hello world!")
pyperclip.paste()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 import pyperclip
#       2 pyperclip.copy("Hello world!")
#       3 pyperclip.paste()
#
# ModuleNotFoundError: No module named 'pyperclip'

# %% [markdown]
# ## 6.3

# %% [markdown]
# ## 6.6

# %%
"Remember, remember, the fifth of Novermber.".split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'Novermber.']

# %%
tableData = [["apples","orange","cherries","banana"],
             ["Alice","Bob","Carol","Divid"],
             ["dogs","cats","moose","goose"]]

tableData[1]
def printtable(tableData):
   
        print(tableData[1],tabelData[2],tableData[3])
printtable(tableData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 9
#       6 def printtable(tableData):
#       8         print(tableData[1],tabelData[2],tableData[3])
# ----> 9 printtable(tableData)
#
# Cell In[144], line 8, in printtable(tableData)
#       6 def printtable(tableData):
# ----> 8         print(tableData[1],tabelData[2],tableData[3])
#
# NameError: name 'tabelData' is not defined

# %%
leftWidth,rightWidth

for k in tableData():
      print(tableData.)

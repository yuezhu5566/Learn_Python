# %% [markdown]
# # 5.0

# %%
myCat={"size":"fat",
       "color":"gray",
       "disposition":"loud"
    
}

# %%
myCat["size"]
# Out:
# 'fat'

# %%
"My cat has "+myCat["color"]+" fur"
# Out:
# 'My cat has gray fur'

# %%
spam={12345:"luggage combination", 42:"The answer"}

# %%
spam
# Out:
# {12345: 'luggage combination', 42: 'The answer'}

# %%
birthdays={"Alice":"Apr 1","Bob":"Dec 23","Carole":"Mar 4"}
while True:
    print("Enter a name :(blank to quit)")
    name =input()
    if name=="":
        break
    if name in birthdays:
        print(birthdays[name]+" is the birthday of " + name)
    else:
        print("i do not have birthday information for "+name)
        print("What is their birthday?")
        bday=input()
        birthdays[name]=bday
        print("birthday database updated.")
# Out:
# Enter a name :(blank to quit)
#  ss
# i do not have birthday information for ss
# What is their birthday?
#  May 5
# birthday database updated.
# Enter a name :(blank to quit)

# %%
birthdays
# Out:
# {'Alice': 'Apr 1', 'Bob': 'Dec 23', 'Carole': 'Mar 4', 'ss': 'May 5'}

# %%
#5.1.2

# %%
spam={"color":"red","age":42}
for v in spam.values():
    print(v)

# 42中 没有加“”“
# Out:
# red
# 42

# %%
for k in spam.keys():
    print(k)
# Out:
# color
# age

# %%
for i in spam.items():
    print(i)
# Out:
# ('color', 'red')
# ('age', 42)

# %%
spam={"color":"red","age":42}      
spam.keys()
# Out:
# dict_keys(['color', 'age'])

# %%
list(spam.keys())
# Out:
# ['color', 'age']

# %%
spam={"color":"red","age":42}   

for v in spam.items():
    print("Key: ", + k + "Value:" + str(v))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       1 spam={"color":"red","age":42}
#       3 for v in spam.items():
# ----> 4     print("Key: ", + k + "Value:" + str(v))
#
# TypeError: bad operand type for unary +: 'str'

# %%
spam={"name":"Zophie","age":7}
"name" in spam.keys()
# Out:
# True

# %%
"Zophie" in spam.values()
# Out:
# True

# %%
"color" in spam.keys()
# Out:
# False

# %%
"color" not in spam.keys()
# Out:
# True

# %%
"color" in spam
# Out:
# False

# %%
#5.1.4
picnicItems={"apples":5,"cups":2}
"I am bringing " +str(picnicItems.get("cups",0))+"cups."
# Out:
# 'I am bringing 2cups.'

# %%
picnicItems={"apples":5,"cups":2}
picnicItems.get("cups",0)
# Out:
# 2

# %%
"I am bringing " + str(picnicItems.get("eggs",0))+" eggs."
# Out:
# 'I am bringing 0 eggs.'

# %% [markdown]
# #### 5.1.5

# %%
#. spam={"name":"Pooka","age": 5}
# if "color" not in spam:
#     spam["color"]="black"

# %% [markdown]
# spam

# %%
spam={"name":"Pooka","age":5}
spam.setdefault("color","black")
spam
# Out:
# {'name': 'Pooka', 'age': 5, 'color': 'black'}

# %%
spam.setdefault("color","white")
spam
# Out:
# {'name': 'Pooka', 'age': 5, 'color': 'black'}

# %% [raw]
# # 对一句话的count

# %%
message="It was a bright cold day in April, and the clocks were striking thirteen."
count={}
for character in message:
    count.setdefault(character,0)
    count[character]=count[character]+1
print(count)
# Out:
# {'I': 1, 't': 6, ' ': 13, 'w': 2, 'a': 4, 's': 3, 'b': 1, 'r': 5, 'i': 6, 'g': 2, 'h': 3, 'c': 3, 'o': 2, 'l': 3, 'd': 3, 'y': 1, 'n': 4, 'A': 1, 'p': 1, ',': 1, 'e': 5, 'k': 2, '.': 1}

# %% [markdown]
# 5.2 #####

# %% [markdown]
# ## 5.2 漂亮打印

# %%
import pprint
message= "It was a bright cold day in April, and the clocks were striking thirteen."
count={}

for character in message:
    count.setdefault(character,0)
    count[character]=count[character]+1
pprint.pprint(count)
# Out:
# {' ': 13,
#  ',': 1,
#  '.': 1,
#  'A': 1,
#  'I': 1,
#  'a': 4,
#  'b': 1,
#  'c': 3,
#  'd': 3,
#  'e': 5,
#  'g': 2,
#  'h': 3,
#  'i': 6,
#  'k': 2,
#  'l': 3,
#  'n': 4,
#  'o': 2,
#  'p': 1,
#  'r': 5,
#  's': 3,
#  't': 6,
#  'w': 2,
#  'y': 1}

# %% [markdown]
# ## 5.3

# %% [markdown]
# ### 5.3.1

# %%
theBoard={"top-L": "", "top-M": "", "top-R": "",
          "mid-L": "", "mid-M": "", "mid-R": "",
          "low-L": "", "low-M": "", "low_R": "",
         }

# %%
theBoard={"top-L": "O", "top-M": "O", "top-R": "O",
          "mid-L": "X", "mid-M": "X", "mid-R": "",
          "low-L": "", "low-M": "", "low_R": "X",
         }

# %%
theBoard={"top-L": "", "top-M": "", "top-R": "",
          "mid-L": "", "mid-M": "", "mid-R": "",
          "low-L": "", "low-M": "", "low-R": "",
         }

# %%
theBoard={ "top-L": "O", "top-M": "O", "top-R": "O",
           "mid-L": "X", "mid-M": "X", "mid-R": " ",
          "low-L": " ", "low-M": " ", "low-R": "X"}

def printBoard(board):
    print(board["top-L"] + "|" +board["top-M"]+ "|" + board["top-R"])
    print("-+-+-")
    print(board["mid-L"] + "|" +board["mid-M"]+ "|" + board["mid-R"])
    print("-+-+-")
    print(board["low-L"] + " " +board["low-M"]+ "|" + board["low-R"])
 
printBoard(theBoard)
# Out:
# O|O|O
# -+-+-
# X|X|
# -+-+-
#    |X

# %%
theBoard={"top-L": "", "top-M": "", "top-R": "",
          "mid-L": "", "mid-M": "", "mid-R": "",
          "low-L": "", "low-M": "", "low-R": "",
         }

def printBoard(board):
    print(board["top-L"] + "|" +board["top-M"]+ "|" + board["top-R"])
    print("-+-+-")
    print(board["mid-L"] + "|" +board["mid-M"]+ "|" + board["mid-R"])
    print("-+-+-")
    print(board["low-L"] + "|" +board["low-M"]+ "|" + board["low-R"])

turn="X"
for i in range(9):
    printBoard(theBoard)
    print("Turn for " + turn +" . Move on which space?")
    move = input()
    theBoard[move]=turn
    if turn=="X":
        turn="0"
    else:
        turn=="X"
printBoard(theBoard)
# Out:
# ||
# -+-+-
# ||
# -+-+-
# ||
# Turn for X . Move on which space?
#  mid-L
# ||
# -+-+-
# X||
# -+-+-
# ||
# Turn for 0 . Move on which space?
#  low-R
# ||
# -+-+-
# X||
# -+-+-
# ||0
# Turn for 0 . Move on which space?
#  mid-M
# ||
# -+-+-
# X|0|
# -+-+-
# ||0
# Turn for 0 . Move on which space?
#  low-M
# ||
# -+-+-
# X|0|
# -+-+-
# |0|0
# Turn for 0 . Move on which space?
#  top-L
# 0||
# -+-+-
# X|0|
# -+-+-
# |0|0
# Turn for 0 . Move on which space?
#  top-M
# 0|0|
# -+-+-
# X|0|
# -+-+-
# |0|0
# Turn for 0 . Move on which space?
#  low-L
# 0|0|
# -+-+-
# X|0|
# -+-+-
# 0|0|0
# Turn for 0 . Move on which space?
#  mid-R
# 0|0|
# -+-+-
# X|0|0
# -+-+-
# 0|0|0
# Turn for 0 . Move on which space?
#  top-R
# 0|0|0
# -+-+-
# X|0|0
# -+-+-
# 0|0|0

# %% [markdown]
# ### 5.3.2

# %%
allGuests={"Alice":{"apples":5,"pretzels":12},
           "Bob":{"ham sandwiches": 3, "apple" :2},
           "Carol": {"cups" : 3 , "apple pies" :1 }
          }
def totalBrought(guest,item):
    numBrought=0
    for k, v in guests.item():
        numBrought = numBrought + v.get(item,0)
    return numBrought

print("Number of things being brought:")
print("-Apples"+ str(totalBrought(allGuests,"apples")))
print("-Cups" + str(totalBrought(allGuests,"cups")))
print("-Cukes" + str(totalBrought(allGuests,"cakes")))
print("-Ham Sndwiches" + str(totalBrought(allGuests,"ham sandwiches")))
print("-Apple Pies" + str(totalBrought(allGuests,"apple pies")))
# Out:
# Number of things being brought:

# %% [markdown]
# a
